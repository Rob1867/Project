# %% [markdown]
# # Import packages and Data

# %%
import pandas as pd
import logging
import win32com.client as win32
import matplotlib.pyplot as plt


#from tabulate import tabulate

# %% [markdown]
# Configure logging

# %%
logging.basicConfig(
    level = logging.INFO,
    format = "%(asctime)s - %(levelname)s - %(message)s",
    handlers= [
        logging.StreamHandler(), # log to console
        logging.FileHandler("log.txt"), # log to txt file
    ],
)

# %% [markdown]
# Import visual condition data

# %%
vi_filepath = r'C:\Users\robert.everitt\OneDrive - National Grid\Data Engineering Course\Data\Visual inspections Results (E0309B).xlsx'

logging.info(f"Attempting to read data from {vi_filepath}")

try:
    df_vi = pd.read_excel(vi_filepath,)
    logging.info(f"Sucessully read data")
except Exception as e:
    logging.error(f"Error reading file: {e}")

#remove leading and trailing whitespace
df_vi.columns = df_vi.columns.str.strip()
# Out:
# 2026-04-24 14:14:50,116 - INFO - Attempting to read data from C:\Users\robert.everitt\OneDrive - National Grid\Data Engineering Course\Data\Visual inspections Results (E0309B).xlsx
# c:\Users\Robert.Everitt\OneDrive - National Grid\Data Engineering Course\Project\Project\RMEvenv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2026-04-24 14:17:21,091 - INFO - Sucessully read data

# %% [markdown]
# Import importance scores for questions

# %%
importance_filepath = r'C:\Users\robert.everitt\OneDrive - National Grid\Data Engineering Course\Data\Importance_Scores.xlsx'

logging.info(f"Attempting to read data from {importance_filepath}")

try:
    df_importance = pd.read_excel(importance_filepath)
    logging.info(f"Sucessully read data")
except Exception as e:
    logging.error(f"Error reading file: {e}")

#remove leading and trailing whitespace
df_importance.columns = df_importance.columns.str.strip()
# Out:
# 2026-04-24 14:17:21,104 - INFO - Attempting to read data from C:\Users\robert.everitt\OneDrive - National Grid\Data Engineering Course\Data\Importance_Scores.xlsx
# 2026-04-24 14:17:21,270 - INFO - Sucessully read data

# %% [markdown]
# import expected script versions

# %%
exp_script_versions_filepath = r'C:\Users\robert.everitt\OneDrive - National Grid\Data Engineering Course\Data\Script_Versions.xlsx'

logging.info(f"Attempting to read data from {exp_script_versions_filepath}")

try:
    df_exp_script_versions = pd.read_excel(exp_script_versions_filepath)
    logging.info(f"Sucessully read data")
except Exception as e:
    logging.error(f"Error reading file: {e}")

df_exp_script_versions.columns = df_exp_script_versions.columns.str.strip()
# Out:
# 2026-04-24 14:17:21,285 - INFO - Attempting to read data from C:\Users\robert.everitt\OneDrive - National Grid\Data Engineering Course\Data\Script_Versions.xlsx
# 2026-04-24 14:17:21,313 - INFO - Sucessully read data

# %% [markdown]
# # Define Functions

# %% [markdown]
# Define a function to Find the first row containing 'search_text', remove rows above it, and set it as column names.

# %%
def clean_dataframe(df, search_text):

    # Find the index of the first occurrence of the search text
    idx = df[df.apply(lambda row: row.astype(str).str.contains(search_text, case=False).any(), axis=1)].index
    
    if idx.empty:
        raise ValueError(f"'{search_text}' not found in the DataFrame.")
    
    # Get the first matching index
    first_match_idx = idx[0]
    
    # Update the DataFrame by removing rows above the match
    df = df.iloc[first_match_idx:].reset_index(drop=True)
    
    # Set the first row as column names and drop it from the DataFrame
    df.columns = df.iloc[0]
    df = df[1:].reset_index(drop=True)
    
    return df

# %% [markdown]
# Define a function to check if Script Activity IDs all have unique date

# %%
def check_consistent_dates(df, reference_col, date_col):
    """
    Checks if a given reference number always corresponds to the same date
    in a Pandas DataFrame.

    Args:
        df (pd.DataFrame): The input DataFrame.
        reference_col (str): The name of the column containing reference numbers.
        date_col (str): The name of the column containing dates.

    Returns:
        dict: A dictionary indicating consistency.
              - If all consistent: {'consistent': True}
              - If inconsistent: {'consistent': False, 'violating_references': list_of_references}
    """
    # Group by the reference column and count the number of unique dates for each reference
    date_counts = df.groupby(reference_col)[date_col].nunique()

    # Identify reference numbers that have more than one unique date
    violating_references = date_counts[date_counts > 1].index.tolist()

    if not violating_references:
        return {'consistent': True}
    else:
        return {'consistent': False, 'violating_references': violating_references}

# %% [markdown]
# Define a function to return the maximum script version for each script in the visual condition data, for comparision with those in df_Script_Versions. If script version in data is higher, this will need checking to ensure there is still an importance score for all questions

# %%
def get_max_script_versions(df):
    # Get unique Script IDs
    unique_script_ids = df['Script ID'].unique()
    
    # Initialize a dictionary to store results
    max_versions = {}
    
    # Loop through each unique Script ID
    for script_id in unique_script_ids:
        # Filter the DataFrame for the current Script ID
        filtered_df = df[df['Script ID'] == script_id]
        
        # Find the maximum Script Version Number
        max_version = filtered_df['Script Version Number'].max()
        
        # Store the result in the dictionary
        max_versions[script_id] = max_version
    
    # Convert the dictionary to a DataFrame
    result_df = pd.DataFrame(list(max_versions.items()), columns=['Script ID', 'Script Version Number'])
    
    return result_df

# %% [markdown]
# # Transform Data

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# User defined function to remove blank rows at the top and set columns headers

# %%
df_vi_clean = clean_dataframe(df_vi,'Location Code')

# %% [markdown]
# ## Data Standardization

# %% [markdown]
# Define column types

# %%
date_columns = ['Inspection Date']
int_columns = ['Response Score', 'Script Item Number']
string_columns = ['Location Code','Plant Number','Installed Component','Installed Modifier','Script ID', 
                  'Script Description','Attribute ID','Questions','Response Description', 'Document Link', 
                  'Script Activity ID','Script Result ID','Site','Work Group','Zone','Script Version Number']

# %% [markdown]
# Convert data types based on column types above

# %%
for col in date_columns:
    df_vi_clean[col] = df_vi_clean[col].astype(str)
    df_vi_clean[col] = pd.to_datetime(df_vi_clean[col], errors='coerce').dt.strftime('%d/%m/%Y')

for col in int_columns:
    df_vi_clean[col] = pd.to_numeric(df_vi_clean[col], errors='coerce')

for col in string_columns:
    df_vi_clean[col] = df_vi_clean[col].astype(str, errors='ignore')

# %% [markdown]
# Create a reduced version of the cleaned visual inspection dataframe, by combining only the columns needed into a new dataframe

# %% [markdown]
# Create a copy of `df_vi_reduced` to avoid *SettingWithCopyWarning* error.

# %%
# Combine all columns into one list
selected_columns = date_columns + int_columns + string_columns

# Select only the specified columns
df_vi_reduced = df_vi_clean[selected_columns]

df_vi_reduced_copy = df_vi_reduced.copy()

logging.info(f"Visual inspection data cleansed and standardized")
# Out:
# 2026-04-24 14:18:48,273 - INFO - Visual inspection data cleansed and standardized

# %% [markdown]
# ## Data Enrichment 1

# %%
df_not_available = df_vi_reduced_copy[
    (df_vi_reduced_copy['Questions'] == 'Is the asset available?') &
    (df_vi_reduced_copy['Response Description'] == 'NO')
]

df_not_available.head()

logging.info(f"Unavailable assets stored in df_not_available")
# Out:
# 2026-04-24 14:18:48,354 - INFO - Unavailable assets stored in df_not_available

# %%
df_no_deterioration = df_vi_reduced_copy[
    (df_vi_reduced_copy['Questions'].str.contains('Do you want to report any condition deterioration of the asset', na=False)) &
    (df_vi_reduced_copy['Response Description'] == 'NO')
]

df_no_deterioration.head()

logging.info(f"Assets with no deterioration reported stored in df_no_deterioration")
# Out:
# 2026-04-24 14:18:48,594 - INFO - Assets with no deterioration reported stored in df_no_deterioration

# %%
# Adding a new column with the first 5 characters of 'original_column'
df_vi_reduced_copy.loc[:,'5Char_Site_Code'] = df_vi_reduced_copy['Location Code'].str[:5]

df_vi_reduced_copy.loc[:,'Civil Item'] = df_vi_reduced_copy['Attribute ID'].str.contains('CIV').replace({True: 'Civil Item', False: None})

# %%
# Specify the columns to check
check_column = 'Civil Item' 
target_column = 'Attribute ID'

# %%
# Initialize a list to store the indices of matches
matches = []

# %%
# Iterate through the DataFrame
for i in range(len(df_vi_reduced_copy) - 1):  # -1 to avoid index out of range
    if df_vi_reduced_copy[check_column].iloc[i] == 'Civil Item':
        # Start checking the next rows for 'VIGEN05'
        j = i + 1
        while j < len(df_vi_reduced_copy) and df_vi_reduced_copy[target_column].iloc[j] == 'VIGEN05':
            matches.append(j)  # Store the index of 'VIGEN05'
            j += 1  # Move to the next row

for row in matches:
    df_vi_reduced_copy.at[row, check_column] = 'Civil Photo'

df_vi_civil = df_vi_reduced_copy[df_vi_reduced_copy['Civil Item'].notna()]

logging.info(f"Civil Items and Photos identified in df_vi_civil")
# Out:
# 2026-04-24 14:18:52,431 - INFO - Civil Items and Photos identified in df_vi_civil

# %%
df_vi_civil_items = df_vi_civil[df_vi_civil['Civil Item'] == 'Civil Item']

df_vi_civil_items.head()
# Out:
# 0  Inspection Date  Response Score  Script Item Number Location Code  \
# 11      01/08/2022             0.0                   7         SUND4
# 13      01/08/2022            20.0                  13         SUND4
# 19      01/08/2022             0.0                  26         SUND4
# 20      01/08/2022             0.0                  31         SUND4
# 21      01/08/2022             0.0                  45         SUND4
#
# 0  Plant Number Installed Component Installed Modifier Script ID  \
# 11   SUND4X30VT                 VT                   B   RVIVTAA
# 13   SUND4X30VT                 VT                   B   RVIVTAA
# 19   SUND4X30VT                 VT                   B   RVIVTAA
# 20   SUND4X30VT                 VT                   B   RVIVTAA
# 21   SUND4X30VT                 VT                   B   RVIVTAA
#
# 0         Script Description Attribute ID  ...  \
# 11  VT S/S VISUAL INSPECTION    VICIVCN01  ...
# 13  VT S/S VISUAL INSPECTION    VICIVMT01  ...
# ...

# %% [markdown]
# ## Data Validation

# %% [markdown]
# ### Script Versions

# %% [markdown]
# Create dataframe of maximum script versions from the visual inspection data using user defined function

# %%
df_vi_script_versions = get_max_script_versions(df_vi_civil_items)

# %% [markdown]
# Convert data in `Script Version Number` to a numeric value

# %%
df_vi_script_versions['Script Version Number'] = pd.to_numeric(df_vi_script_versions['Script Version Number'], errors='coerce')

# %% [markdown]
# Merge `df_vi_script_versions` and `df_Script_Versions` on `Script ID`. Look for any descrepancies where the maximum script version from the visual inspection data is greater than the expected maximum script version.
# Return either a list of descripancies, or confirmation that there are no descrepancies.
# If there are descripancies, it need to be checked that there aren't any new questions on the updated scripts that don't have importance scores assigned

# %%
# Merge dataframes on 'Script ID'
merged_df = pd.merge(df_vi_script_versions, df_exp_script_versions, on='Script ID', suffixes=('_VI', '_Exp'))

# Check for version discrepancies
discrepancies = merged_df[merged_df['Script Version Number_VI'] > merged_df['Script Version Number_Exp']]

# Get the list of Script IDs where the condition is true
script_ids_with_issues = discrepancies['Script ID'].tolist()

# Output the result

if not script_ids_with_issues:
    logging.info(f"The list of script IDs with version issues is empty.")
else:
    logging.info(f"The following script IDs have version issues: {script_ids_with_issues}")
# Out:
# 2026-04-24 14:18:52,660 - INFO - The following script IDs have version issues: ['RVSGANAA', 'RVSCIVAA']

# %%
# Separate problematic rows into a new dataframe
problematic_df = df_vi_civil_items[df_vi_civil_items['Script ID'].isin(script_ids_with_issues)]

# Remove problematic rows from the original dataframe
clean_df = df_vi_civil_items[~df_vi_civil_items['Script ID'].isin(script_ids_with_issues)]

#Save problematic rows dataframe to separate file
problematic_df.to_csv('problematic_scripts.csv', index=False)

if script_ids_with_issues:
    logging.info(f"{len(script_ids_with_issues)} rows with script version issues removed and stored in probematic_scripts.csv")
# Out:
# 2026-04-24 14:18:52,744 - INFO - 2 rows with script version issues removed and stored in probematic_scripts.csv

# %%
print(merged_df)
# Out:
#        Script ID  Script Version Number_VI  Script Version Number_Exp
# 0        RVIVTAA                         6                          6
# 1       RVIDISAA                         8                          8
# 2        RVICTAA                         8                          8
# 3        RVIESAA                         7                          7
# 4        RVIBHAA                         7                          7
# 5       RVIGCBAA                         7                          7
# 6       RVICSEAA                         9                         10
# 7       RVIVCTAA                         4                          4
# 8       RVISPIAA                         5                          6
# 9      RVIABCBAA                         8                          8
# 10       RVINEAA                         4                          4
# 11    RVSBUILDAA                         9                          9
# ...

# %% [markdown]
# ### Script Activity ID as unique identifier

# %%
print(df_vi_civil_items[df_vi_civil_items['Script Activity ID'] == 'S-0659897'])
# Out:
# 0  Inspection Date  Response Score  Script Item Number Location Code  \
# 11      01/08/2022             0.0                   7         SUND4
# 13      01/08/2022            20.0                  13         SUND4
# 19      01/08/2022             0.0                  26         SUND4
# 20      01/08/2022             0.0                  31         SUND4
# 21      01/08/2022             0.0                  45         SUND4
#
# 0  Plant Number Installed Component Installed Modifier Script ID  \
# 11   SUND4X30VT                 VT                   B   RVIVTAA
# 13   SUND4X30VT                 VT                   B   RVIVTAA
# 19   SUND4X30VT                 VT                   B   RVIVTAA
# 20   SUND4X30VT                 VT                   B   RVIVTAA
# 21   SUND4X30VT                 VT                   B   RVIVTAA
#
# 0         Script Description Attribute ID  ...  \
# 11  VT S/S VISUAL INSPECTION    VICIVCN01  ...
# 13  VT S/S VISUAL INSPECTION    VICIVMT01  ...
# ...

# %%
# Call the function with the copied DataFrame
result_consistent = check_consistent_dates(df_vi_civil_items, 'Script Activity ID', 'Inspection Date')

# %%
print(result_consistent)
# Out:
# {'consistent': True}

# %%
if result_consistent['consistent']:
    print("Result: All reference numbers consistently have the same date.")
    logging.info("Date consistency check passed")
else:
    print(f"Result: The following reference numbers have inconsistent dates: {result_consistent['violating_references']}")
    logging.error(f"Date consistency check failed")
    outlook = win32.Dispatch("Outlook.Application")
    mail = outlook.CreateItem(0)
    mail.To = "robert.everitt@nationalgrid.com"
    mail.Subject = "Notebook run status"
    mail.Body = (f"Runtime error - date consistance check failed {result_consistent}")
    mail.Send()
    raise RuntimeError ("Consistency check returned {'consistent': False}")
print("\n" + "="*50 + "\n")
# Out:
# 2026-04-24 14:18:52,875 - INFO - Date consistency check passed
# Result: All reference numbers consistently have the same date.
#
# ...

# %%
df_vi_civil_items.head()
# Out:
# 0  Inspection Date  Response Score  Script Item Number Location Code  \
# 11      01/08/2022             0.0                   7         SUND4
# 13      01/08/2022            20.0                  13         SUND4
# 19      01/08/2022             0.0                  26         SUND4
# 20      01/08/2022             0.0                  31         SUND4
# 21      01/08/2022             0.0                  45         SUND4
#
# 0  Plant Number Installed Component Installed Modifier Script ID  \
# 11   SUND4X30VT                 VT                   B   RVIVTAA
# 13   SUND4X30VT                 VT                   B   RVIVTAA
# 19   SUND4X30VT                 VT                   B   RVIVTAA
# 20   SUND4X30VT                 VT                   B   RVIVTAA
# 21   SUND4X30VT                 VT                   B   RVIVTAA
#
# 0         Script Description Attribute ID  ...  \
# 11  VT S/S VISUAL INSPECTION    VICIVCN01  ...
# 13  VT S/S VISUAL INSPECTION    VICIVMT01  ...
# ...

# %% [markdown]
# ## Data Enrichment 2

# %%
# Define the valid response scores
valid_scores = [0, 20, 40, 60, 80, 100]

# Filter the DataFrame
df_scores = df_vi_civil_items[df_vi_civil_items['Response Score'].isin(valid_scores) & ~df_vi_civil_items['Response Description'].isin(['YES', 'NO', 'Non-Metallic']) & 
    df_vi_civil_items['Response Description'].notnull()]

df_scores.head()

#### NEED TO INCLUDE 'ITEMS NOT AVAILABLE' AND ITEMS WHERE THERE IS NO DETERIORATION TO REPORT ###
# Out:
# 0  Inspection Date  Response Score  Script Item Number Location Code  \
# 11      01/08/2022             0.0                   7         SUND4
# 13      01/08/2022            20.0                  13         SUND4
# 31      01/08/2022             0.0                   7         SUND4
# 33      01/08/2022             0.0                  11         SUND4
# 81      02/08/2022             0.0                   7         SUND4
#
# 0  Plant Number Installed Component Installed Modifier Script ID  \
# 11   SUND4X30VT                 VT                   B   RVIVTAA
# 13   SUND4X30VT                 VT                   B   RVIVTAA
# 31    SUND4X303                 DIS                nan  RVIDISAA
# 33    SUND4X303                 DIS                nan  RVIDISAA
# 81    SUND4X124                 DIS                nan  RVIDISAA
#
# 0           Script Description Attribute ID  ...  \
# 11    VT S/S VISUAL INSPECTION    VICIVCN01  ...
# 13    VT S/S VISUAL INSPECTION    VICIVMT01  ...
# ...

# %% [markdown]
# **Explanation:**\
# `isin` is used to exclude all the rows where `Response Score` is not one of the values in `valid_scores`
# Negation with ~: The ~ operator is used to negate the condition, meaning we want to exclude rows where 'Response Description' is in the specified list.\
# `notnull()` Method: The `notnull()` method is used to ensure that we only keep rows where `Response Description` is not null.\
# Combining Conditions: The conditions are combined using the & operator to ensure both criteria are met.\
# The resulting DataFrame `df_scores` will contain only the rows that meet both filtering criteria.

# %% [markdown]
# Add a new column in df_final which concatenates script and question. This will be used to link the importance scores

# %%
# Concatenating two columns into a new column with a space in between

df_final = df_scores.copy()

df_final.loc[:,'Script and Question'] = df_final['Script Description'] + ' ' + df_final['Questions']

# %% [markdown]
# Merge df_final and df_importance to add in inportance scores associated with each script/queston

# %%
# Merging df_final with df_importance based on 'Script and Question'
df_final = df_final.merge(df_importance[['Script and Question', 'Importance score']], 
                          on='Script and Question', 
                          how='left')

# %% [markdown]
# Add in another column WCS_Element, which contains the componets for each question which will feed into the WCS equation for the whole asset.
# Add in another column which combines the component/question/script activity ID (see explaination in subsequent cells)

# %%
df_final['WCS_Element'] = 1-(df_final['Importance score']/100)*(df_final['Response Score']/100)
#df_final['Component_Q_ScriptActID'] = df_final['Installed Component'] + df_final['Questions'] + df_final['Script Activity ID']
df_final['Q_ScriptActID'] = df_final['Questions'] + df_final['Script Activity ID']

# %% [markdown]
# Create a new column to store the maximum Response Score for each Component_Q_ScriptActID, this will be used later to avoid the situation where we count muliple fence panels/trench covers etc. as concurrent defects on the same asset, leading to very high WCS scores

# %%
# Create a new column to store the maximum Response Score for each Component_Q_ScriptActID
df_final['Max_Response_Score'] = None

# Loop through each row in the DataFrame
for index, row in df_final.iterrows():
    # Get the current Component_Q_ScriptActID
    #current_id = row['Component_Q_ScriptActID']
    current_id = row['Q_ScriptActID']

    # Find the maximum Response Score for the current Component_Q_ScriptActID
    #max_score = df_final[df_final['Component_Q_ScriptActID'] == current_id]['Response Score'].max()
    max_score = df_final[df_final['Q_ScriptActID'] == current_id]['Response Score'].max()

    # Assign the maximum score to the new column
    df_final.at[index, 'Max_Response_Score'] = max_score

# %% [markdown]
# Create a version of the dataframe with only unique values of `Q_ScriptActID`, as we only want one WCS score per `Q_ScriptActID` combination

# %%
# Assuming df is your DataFrame
#df_unique = df_final.drop_duplicates(subset='Component_Q_ScriptActID')
df_unique = df_final.drop_duplicates(subset='Q_ScriptActID')

# %% [markdown]
# Copy to avoid *SettingWithCopyWarning* error.
# Carry out WCS calculation for each `Component_Q_ScriptActID`

# %% [markdown]
# Not sure the code below is right, check what is happening with the WCS test file

# %%
df_unique = df_unique.copy()

df_unique['WCS'] = 1- df_unique.groupby('Script Activity ID')['WCS_Element'].transform('prod')

df_unique.head()
# Out:
#   Inspection Date  Response Score  Script Item Number Location Code  \
# 0      01/08/2022             0.0                   7         SUND4
# 1      01/08/2022            20.0                  13         SUND4
# 2      01/08/2022             0.0                   7         SUND4
# 3      01/08/2022             0.0                  11         SUND4
# 4      02/08/2022             0.0                   7         SUND4
#
#   Plant Number Installed Component Installed Modifier Script ID  \
# 0   SUND4X30VT                 VT                   B   RVIVTAA
# 1   SUND4X30VT                 VT                   B   RVIVTAA
# 2    SUND4X303                 DIS                nan  RVIDISAA
# 3    SUND4X303                 DIS                nan  RVIDISAA
# 4    SUND4X124                 DIS                nan  RVIDISAA
#
#            Script Description Attribute ID  ... Zone Script Version Number  \
# 0    VT S/S VISUAL INSPECTION    VICIVCN01  ...  TCN                     1
# ...

# %%
print(df_unique.columns)
# Out:
# Index(['Inspection Date', 'Response Score', 'Script Item Number',
#        'Location Code', 'Plant Number', 'Installed Component',
#        'Installed Modifier', 'Script ID', 'Script Description', 'Attribute ID',
#        'Questions', 'Response Description', 'Document Link',
#        'Script Activity ID', 'Script Result ID', 'Site', 'Work Group', 'Zone',
#        'Script Version Number', '5Char_Site_Code', 'Civil Item',
#        'Script and Question', 'Importance score', 'WCS_Element',
#        'Q_ScriptActID', 'Max_Response_Score', 'WCS'],
#       dtype='object')

# %%
# Merge df_final with df_unique on Component_Q_ScriptActID
df_unique_clean = df_unique.drop_duplicates(subset='Script Activity ID')

df_final = df_final.merge(df_unique_clean[['Script Activity ID','WCS']], 
                          on='Script Activity ID', 
                          how='left')

# %%
df_final.to_excel(r'C:\Users\robert.everitt\OneDrive - National Grid\Data Engineering Course\WCS_Full.xlsx')

# %% [markdown]
# ## Prepare Asset Health Output

# %%
col = "Script Activity ID"

df_not_available_dedup = df_not_available.drop_duplicates(subset=[col], keep="first")
df_no_deterioration_dedup = df_no_deterioration.drop_duplicates(subset=[col], keep="first")
df_final_dedup = df_final.drop_duplicates(subset=[col], keep="first")

df_not_available_dedup.loc[:,'5Char_Site_Code'] = df_not_available_dedup['Location Code'].str[:5]
df_not_available_dedup.loc[:,'WCS'] = "NaN"
df_no_deterioration_dedup.loc[:,'5Char_Site_Code'] = df_no_deterioration_dedup['Location Code'].str[:5]
df_no_deterioration_dedup.loc[:,'WCS'] = 0

# concatenate into one dataframe for asset health
df_Asset_Health = pd.concat([df_final_dedup, df_not_available_dedup, df_no_deterioration_dedup], ignore_index=True)

# Convert WCS to numeric; invalid strings become NaN
wcs = pd.to_numeric(df_Asset_Health["WCS"], errors="coerce")

# Missing bucket
df_Asset_Health["NaN"] = wcs.isna().astype(int)

# Range buckets (only evaluate for non-missing values)
df_Asset_Health["No defect"] = ((wcs == 0) & wcs.notna()).astype(int)
df_Asset_Health["0-25"]   = ((wcs > 0)  & (wcs < 0.25)  & wcs.notna()).astype(int)
df_Asset_Health["25-50"]  = ((wcs >= 0.25) & (wcs < 0.50)  & wcs.notna()).astype(int)
df_Asset_Health["50-75"]  = ((wcs >= 0.50) & (wcs < 0.75)  & wcs.notna()).astype(int)
df_Asset_Health["75-100"] = ((wcs >= 0.75) & (wcs <= 1) & wcs.notna()).astype(int)



# Drop columns you don't need
cols_to_drop = ["Document Link", "Location Code", "Questions", "Response Description", "Response Score",
                "Script Item Number", "Script Result ID", "Site", "Q_ScriptActID", "Civil Item",
                "Importance score", "Max_Response_Score", "Script and Question", "WCS_Element"
]
df_Asset_Health = df_Asset_Health.drop(columns=cols_to_drop, errors="ignore")

print(df_Asset_Health.shape)
print(df_Asset_Health.head())
# Out:
# (76952, 19)
#   Inspection Date Plant Number Installed Component Installed Modifier  \
# 0      01/08/2022   SUND4X30VT                 VT                   B
# 1      01/08/2022    SUND4X303                 DIS                nan
# 2      02/08/2022    SUND4X124                 DIS                nan
# 3      02/08/2022  SUND4X12CT4                 CT                   R
# 4      02/08/2022  SUND4X12CT4                 CT                   B
#
#   Script ID          Script Description Attribute ID Script Activity ID  \
# 0   RVIVTAA    VT S/S VISUAL INSPECTION    VICIVCN01          S-0659897
# 1  RVIDISAA  DISC S/S VISUAL INSPECTION    VICIVCN01          S-0659910
# 2  RVIDISAA  DISC S/S VISUAL INSPECTION    VICIVCN01          S-0661012
# 3   RVICTAA    CT S/S VISUAL INSPECTION    VICIVCN01          S-0661045
# 4   RVICTAA    CT S/S VISUAL INSPECTION    VICIVCN01          S-0661100
#
#   Work Group Zone Script Version Number 5Char_Site_Code    WCS  NaN  \
# ...

# %% [markdown]
# ## edit code below to make it specfic to this script - taken straight from Copilot

# %%
import numpy as np

# Example mapping: group name -> list of Script Descriptions
group_map = {
    "bay switchgear": [
        "VT S/S VISUAL INSPECTION",
        "DISC S/S VISUAL INSPECTION",
        "CT S/S VISUAL INSPECTION",
        "GCB S/S VISUAL INSPECTION",
        "CSE S/S VISUAL INSPECTION",
        "VCT S/S VISUAL INSPECTION",
        "POST INS S/S VISUAL INSPECTION",
        "ABCB S/S VISUAL INSPECTION",
        "SA S/S VISUAL INSPECTION",
        "OCB S/S VISUAL INSPECTION",
        "ESW S/S VISUAL INSPECTION"
    ],
    "Building": [
        "B/HOUSE S/S VISUAL INSPECTION",
        "RUTINE VISUAL INSPECTION - BUILDING INT",
        "NON-OPS BUILD S/S VISUAL INSPECTION",
    ],
    "Perimeter Security": [
        "FENCE S/S VISUAL INSPECTION"
    ],
    "Roads and Trenches": [
        "ROADS S/S VISUAL INSPECTION",
        "TRENCH RD X S/S VISUAL INSECTION",
        "Routine Visual Inspection - Trench",
        "Routine Visual Inspection - Trench Cross"        
    ],
    "Gantries": [
        "GANTRY S/S VISUAL INSPECTION",
        "GANTRY SUBSCRIPT"
    ],
    "Wound Plant": [
        "SGT S/S VISUAL INSPECTION",
        "NE S/S VISUAL INSPECTION",
        "Earthing transformer",
        "QUAD BOOSTER S/S VISUAL INSPECTION",
        "REACTOR S/S VISUAL INSPECTION",
        "TAP CHANGER S/S VISUAL INSPECTION",
        "BUND S/S VISUAL INSPECTION"
    ],
    "Miscellaneous": [
        "ROUTINE VISUAL INSPECTION - DEFECT",
        "TWB S/S VISUAL INSPECTION",
        "RECEIVER",
        "GAS ZONES S/S VISUAL INSPECTION",
        "MSC S/S VISUAL INSPECTION",
        "COMPRESSOR",
        "BUSHING S/S VISUAL INSPECTION",
        "AIR PANEL"
    ]

}

# (Optional) normalise Script Description text for robust matching
s = (df_Asset_Health["Script Description"]
     .astype(str)
     .str.strip()
)

conditions = [s.isin(desc_list) for desc_list in group_map.values()]
choices = list(group_map.keys())

df_Asset_Health["group"] = np.select(conditions, choices, default="misc")

# %%
output_path = r'C:\Users\robert.everitt\OneDrive - National Grid\Data Engineering Course\WCS_Full_Asset_Health.xlsx'

df_Asset_Health.to_excel(output_path, index=False)

# %%
# Convert WCS to numeric; invalid strings become NaN
wcs = pd.to_numeric(df_final_dedup["WCS"], errors="coerce")

# Missing bucket
df_final_dedup["NaN"] = wcs.isna().astype(int)

# Range buckets (only evaluate for non-missing values)
df_final_dedup["0-25"]   = ((wcs >= 0)  & (wcs < 25)  & wcs.notna()).astype(int)
df_final_dedup["25-50"]  = ((wcs >= 25) & (wcs < 50)  & wcs.notna()).astype(int)
df_final_dedup["50-75"]  = ((wcs >= 50) & (wcs < 75)  & wcs.notna()).astype(int)
df_final_dedup["75-100"] = ((wcs >= 75) & (wcs <= 100) & wcs.notna()).astype(int)
# Out:
# C:\Users\Robert.Everitt\AppData\Local\Temp\ipykernel_25156\1736146232.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_dedup["NaN"] = wcs.isna().astype(int)
# C:\Users\Robert.Everitt\AppData\Local\Temp\ipykernel_25156\1736146232.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_dedup["0-25"]   = ((wcs >= 0)  & (wcs < 25)  & wcs.notna()).astype(int)
# C:\Users\Robert.Everitt\AppData\Local\Temp\ipykernel_25156\1736146232.py:9: SettingWithCopyWarning:
# ...

# %%
#df_final.to_parquet("my_dataset.parquet", compression="snappy", index=False)

# %% [markdown]
# ## Data Visualisation

# %%
# Count unique Script Activity IDs (exclude NaN by default)
unique_counts = {
    'Not Available': df_not_available['Script Activity ID'].nunique(dropna=True),
    'No Deterioration': df_no_deterioration['Script Activity ID'].nunique(dropna=True),
    'Scored Assets': df_final['Script Activity ID'].nunique(dropna=True),
}

# Plot
plt.figure(figsize=(7, 4))
bars = plt.bar(unique_counts.keys(), unique_counts.values(),
               color=['steelblue', 'orange', 'seagreen'])

# Labels & title
plt.title('Unique "Script Activity ID" Count per DataFrame')
plt.ylabel('Unique count')

# Annotate bars with counts
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height + 0.1,
             f'{int(height)}', ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
by_asset_type_columns = ['Installed Component', 'Script Activity ID', 'WCS']

df_by_asset_type = df_unique_clean[by_asset_type_columns]

df_by_asset_type.head()
# Out:
#   Installed Component Script Activity ID    WCS
# 0                 VT           S-0659897  0.150
# 2                 DIS          S-0659910  0.000
# 4                 DIS          S-0661012  0.310
# 6                 CT           S-0661045  0.450
# 8                 CT           S-0661100  0.531

# %% [markdown]
# *Read the code below and understand it - taken from copilot*

# %%
# --- Configuration ---
threshold = 0.75
count_unique_script_ids = False  # True -> count unique Script Activity IDs; False -> count rows

# --- Create WCS band labels ---
df_by_asset_type['WCS Band'] = pd.NA
df_by_asset_type.loc[df_by_asset_type['WCS'] >= threshold, 'WCS Band'] = f'>= {threshold}'
df_by_asset_type.loc[df_by_asset_type['WCS'] <  threshold, 'WCS Band'] = f'< {threshold}'

# --- Aggregate counts per Installed Component per WCS band ---
if count_unique_script_ids:
    agg_df = df_by_asset_type.groupby(['Installed Component', 'WCS Band'])['Script Activity ID'].nunique().reset_index(name='Count')
else:
    agg_df = df_by_asset_type.groupby(['Installed Component', 'WCS Band']).size().reset_index(name='Count')

# Pivot to wide format for stacked bars
pivot_df = agg_df.pivot(index='Installed Component', columns='WCS Band', values='Count').fillna(0)

# Order segments: below threshold first, then above
col_order = [c for c in pivot_df.columns if str(c).startswith('<')] + [c for c in pivot_df.columns if str(c).startswith('>=')]
pivot_df = pivot_df[col_order]

# --- Plot ---
plt.figure(figsize=(8, 4.5))
colors = ['#f28e2b', '#4e79a7']  # orange for below, blue for above
bottom = None

for i, col in enumerate(pivot_df.columns):
    plt.bar(pivot_df.index, pivot_df[col], bottom=bottom, label=col, color=colors[i % len(colors)])
    bottom = pivot_df.iloc[:, :i+1].sum(axis=1)  # update stacking baseline

# Annotate totals on top of each bar
totals = pivot_df.sum(axis=1)
for x, total in zip(range(len(pivot_df.index)), totals):
    plt.text(x, total + 0.05, str(int(total)), ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.title('Counts by Installed Component, split by WCS threshold')
plt.ylabel('Count')
plt.xlabel('Installed Component')
plt.legend(title='WCS Band', loc='upper right')
plt.xticks(rotation=90)
plt.tight_layout()
# Out:
# C:\Users\Robert.Everitt\AppData\Local\Temp\ipykernel_25156\2688123734.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_by_asset_type['WCS Band'] = pd.NA

# %% [markdown]
# ## Data Enrichment 3

# %% [markdown]
# Create tables in ETIP format

# %%
columns = [
    "Title", "Unique ID", "Source", "ALC Status", "Site", "Work Group", "Zone",
    "Circuit/Asset Impacted", "Functional Position", "How was the Defect Discovered?",
    "Sub Component Affected", "Symptom of Asset", "Cause of Asset",
    "Asset Fault Condition Classification", "Primary Driver for Entry",
    "Describe the issue with the item of plant:", "Potential Consequences?",
    "Additional Information from Ops", "Any Operational Restrictions? (e.g. TLRs, Hazard zones and etc.)",
    "Does Work Require An Outage", "Links to Pictures (If available)", "Quote Cost (if available)",
    "Raised By:", "Site Contact", "Entry Date", "Asset Lifecycle Category", "Lifecycle Lead",
    "ALC Mail ID", "AL Comments", "Must be Done Date", "C&P Lead / Project Engineer",
    "Scheme No.", "Scheme Title", "Work order number (S)", "Work Description", "BP500 Status",
    "Estimated Delivery Cost", "Delivery Year", "Delivery Comments", "Regulatory Period",
    "C&P and Delivery Status", "Site Duration Estimate", "Resource Requirements",
    "Completed Date", "Created By", "Modified By", "Modified", "Item Type", "Path"
]


# Create empty DataFrame
df_etip = pd.DataFrame(columns=columns)

# %%
# Example setup
# target_df has headers only
target_df = pd.DataFrame(columns=["Asset_Name", "Location", "Class", "WCS", "Criticality"])

# source_df has data (with different column names)
# e.g., source columns: ["Name", "Site", "Category", "WCS", "RiskScore", ...]
# source_df = ...

# 1) Filter rows in source where WCS >= 0.75
filtered_src = df_unique_clean.loc[df_unique_clean["WCS"] >= 0.75].copy()

# 2) Map columns: source -> target
column_map = {
    "Script Activity ID": "Unique ID",
    "Plant Number": "Functional Position",
    "Script Description": "How was the Defect Discovered?"
}

# 3) Keep only columns that exist in source AND target
valid_map = {src: tgt for src, tgt in column_map.items()
             if src in filtered_src.columns and tgt in df_etip.columns}

# 4) Reindex target_df to match filtered source index (so assignment aligns)
target_df = target_df.reindex(filtered_src.index)

# 5) Assign across
for src_col, tgt_col in valid_map.items():
    df_etip[tgt_col] = filtered_src[src_col]

# target_df now contains rows where WCS >= 0.75 with the mapped columns filled

# %%
df_etip['Source'] = 'Plant Status'
df_etip['Raised By:'] = 'ROB EVERITT'
df_etip['Lifecycle Lead'] = 'Robert Everitt'
df_etip['ALC Mail IS'] = 'Robert Everitt'
df_etip['ALC Status'] = 'Asset Lifecycle Review'
df_etip['C&P Lead / Project Engineer'] = 'Steve Barnett'
df_etip['C&P and Delivery Status'] = 'Not Started'
df_etip['Describe the issue with the item of plant:"'] = 'To be confirmed during asset lifecycle review'

# %%
# --- Inputs: adjust these names to your actual columns ---
links_df = df_vi_civil                    # dataframe containing Civil Item and links
etip_df = df_etip                       # your target dataframe
civil_col = "Civil Item"                # column that contains the text 'civil photo'
links_key_col = "Script Activity ID"    # key in df_links
etip_key_col = "Unique ID"              # key in df_etip
link_col = "Document Link"                  # column that contains the actual URLs
output_col = "Links to Pictures (If available)"  # target column in df_etip
sep = " | "                             # separator for concatenated links

# --- 0) Defensive checks ---
for dfname, dfobj, cols in [
    ("df_vi_civil", links_df, [civil_col, links_key_col, link_col]),
    ("df_etip", etip_df, [etip_key_col]),
]:
    missing = [c for c in cols if c not in dfobj.columns]
    if missing:
        raise KeyError(f"{dfname} missing required columns: {missing}")

# Ensure output column exists (optional; pandas will create it on assignment anyway)
if output_col not in etip_df.columns:
    etip_df[output_col] = pd.NA

# --- 1) Filter rows that represent civil photos (case-insensitive) ---
mask_civil_photo = links_df[civil_col].astype(str).str.contains("civil photo", case=False, na=False)
civil_links = links_df.loc[mask_civil_photo, [links_key_col, link_col]].copy()

# Clean links: strip whitespace, drop empty
civil_links[link_col] = civil_links[link_col].astype(str).str.strip()
civil_links = civil_links[civil_links[link_col].ne("")]

# --- 2) Deduplicate links per key ---
civil_links = civil_links.drop_duplicates(subset=[links_key_col, link_col])

# --- 3) Concatenate links per Script Activity ID ---
links_per_id = (
    civil_links
    .groupby(links_key_col, as_index=False)[link_col]
    .agg(lambda s: sep.join(s))
    .rename(columns={link_col: output_col})
)

lookup = links_per_id.set_index(links_key_col)[output_col]

etip_df[output_col] = etip_df[etip_key_col].map(lookup)

# %% [markdown]
# Create a list of Script Activity IDs that are already in etip, then remove them from the etip_table output so Sonia is not inputting them twice

# %%
path = r"C:\Users\Robert.Everitt\OneDrive - National Grid\Data Engineering Course\Project\Project\Data\plant_status.csv"

raw_etip_df = pd.read_csv(
    path,
    encoding="utf-8-sig",   # handles UTF-8 BOM if present
    dtype=str,              # keeps everything as text (avoids mixed-type surprises)
    keep_default_na=False   # keeps blanks as "" instead of NaN (optional)
)

flt_etip_df = raw_etip_df[raw_etip_df["field_1"].str.startswith("S-", na=False)]

s_ids_etip_df = flt_etip_df[["field_1"]]

# %%
print(s_ids_etip_df)
# Out:
#         field_1
# 1     S-2271906
# 2     S-2271909
# 3     S-2234461
# 4     S-2245284
# 5     S-2245285
# ...         ...
# 195   S-2112158
# 196   S-2112151
# 197   S-1501974
# 198   S-1501547
# 1411  S-0369042
#
# [199 rows x 1 columns]

# %%
ids_to_drop = (
    s_ids_etip_df["field_1"]
      .astype(str)
      .str.strip()
)

etip_new_items_df = etip_df.loc[
    ~etip_df["Unique ID"].astype(str).str.strip().isin(ids_to_drop)
].copy()

# %% [markdown]
# # Load

# %% [markdown]
# Export to excel

# %%
from datetime import date

today_str = date.today().strftime("%d.%m.%y")


etip_df.to_excel(r'C:\Users\robert.everitt\OneDrive - National Grid\Data Engineering Course\etip_table.xlsx')

etip_new_items_df.to_excel(
    fr"C:\Users\robert.everitt\OneDrive - National Grid\Data Engineering Course\etip_new_items_{today_str}.xlsx",
    index=False
)

# %% [markdown]
# Send confirmation email

# %%
#outlook = win32.Dispatch("Outlook.Application")
#mail = outlook.CreateItem(0)
#mail.To = "robert.everitt@nationalgrid.com"
#mail.Subject = "Notebook run status"
#mail.Body = "Completed successfully."
#mail.Send()


attachment_path = fr"C:\Users\robert.everitt\OneDrive - National Grid\Data Engineering Course\etip_new_items_{today_str}.xlsx"

outlook = win32.Dispatch("Outlook.Application")
mail = outlook.CreateItem(0)

mail.To = "robert.everitt@nationalgrid.com"
mail.Subject = "Notebook run status"
mail.Body = f"Completed successfully.\n\nAttached: etip_new_items_{today_str}.xlsx"

mail.Attachments.Add(attachment_path)

mail.Send()

# %% [markdown]
# # Next Steps

# %% [markdown]
# Add Lat/Long based on 5 char site code, for visualisation in Power BI or similar

# %% [markdown]
# Something to track which items have already gone to ETIP and only add additional items - Incremental updates
